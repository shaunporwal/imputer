# %%
from imputer import Imputer
import pandas as pd

# %%
df_sim = pd.read_csv('https://raw.githubusercontent.com/shaunporwal/imputer/main/data/sim_medical_data.csv')

# %%
df_sim
# Out:
#    ID  Age  Gender                         Symptoms      Diagnosis  \
# 0   1   32    Male                     Fever, Cough            Flu
# 1   2   45  Female  Chest Pain, Shortness of Breath  Heart Disease
# 2   3   29    Male                            Fever            Flu
# 3   4   51  Female                 Headache, Nausea            NaN
# 4   5   60     NaN              Joint Pain, Fatigue      Arthritis
# 5   6   27  Female                        Back Pain            NaN
# 6   7   34    Male                      Sore Throat           Cold
# 7   8   49     NaN                Cough, Chest Pain  Heart Disease
# 8   9   38  Female                  Fatigue, Nausea            NaN
# 9  10   44    Male                  Fever, Headache            Flu
#
#                    Treatment
# 0                    Tamiflu
# 1  Aspirin, Lifestyle Change
# 2                        NaN
# 3                  Ibuprofen
# 4                     NSAIDs
# 5                        NaN
# ...

# %%
med_data_imputer = Imputer()

# %%
med_data_imputer.fit(data=df_sim)

# %%
med_data_imputer.get_rows_with_na()
# Out:
#    ID  Age  Gender             Symptoms      Diagnosis  Treatment
# 2   3   29    Male                Fever            Flu        NaN
# 3   4   51  Female     Headache, Nausea            NaN  Ibuprofen
# 4   5   60     NaN  Joint Pain, Fatigue      Arthritis     NSAIDs
# 5   6   27  Female            Back Pain            NaN        NaN
# 7   8   49     NaN    Cough, Chest Pain  Heart Disease    Aspirin
# 8   9   38  Female      Fatigue, Nausea            NaN     NSAIDs
# 9  10   44    Male      Fever, Headache            Flu        NaN

# %%
med_data_imputer.hello()
# Out:
# 'Hello from the Imputer class!'
